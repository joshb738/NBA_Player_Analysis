# %% [markdown]
# ### Import generic

# %%
#So first we need to cluster the players on height, weight and stats (Use PCA), 
#after that we would ML on the dataset where we have player and their cluster. 
#year they are in and VORP and or total win share.

# %%
# Importing required modules
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

## ML && PCA
# Standardize the data with StandardScaler().
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
nba_data = pd.read_csv('Resources/dataset_clean.csv')
#, index_col='Player'

# %%
## Drop height since the format is 5-10 and not "cm" unit
del nba_data['height']
# nba_data = nba_data.drop(columns="Player")

del nba_data['blanl']
del nba_data['blank2']
del nba_data['3P%']
del nba_data['FT%']

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
nba_label_df = pd.DataFrame(nba_data.Player)
nba_label_df.head()
# Out:
#                 Player
# 0    Tariq Abdul-Wahad
# 1  Shareef Abdur-Rahim
# 2  Shareef Abdur-Rahim
# 3  Shareef Abdur-Rahim
# 4  Shareef Abdur-Rahim

# %%
del nba_data['Player']

# %% [markdown]
# ## Generic Information

# %%
nba_data.head(15)
# Out:
#     Year  Age   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  ...  TRB  AST  \
# 0   2003   28  14   204  12.4  0.470  0.017  0.103   7.6  14.0  ...   40   21
# 1   2003   26  81  3087  19.9  0.566  0.051  0.457   6.7  17.8  ...  677  242
# 2   2004   27  85  2684  19.9  0.557  0.032  0.407   8.2  19.0  ...  639  174
# 3   2005   28  54  1867  18.7  0.581  0.058  0.379   7.9  16.0  ...  392  111
# 4   2006   29  72  1961  17.2  0.588  0.035  0.440   6.4  14.8  ...  357  149
# 5   2007   30  80  2015  13.1  0.524  0.031  0.358   7.0  16.4  ...  398  109
# 6   2003   25  66  1360   9.3  0.459  0.113  0.289   3.3   6.8  ...  118   79
# 7   2003   24  80  2318   9.9  0.455  0.005  0.153   6.5  14.9  ...  425   54
# 8   2004   25  45   616  10.5  0.449  0.000  0.167   7.9  14.7  ...  119   16
# 9   2005   26  36   519  14.2  0.512  0.000  0.158   9.0  13.3  ...   99   18
# 10  2006   27  54   701  11.5  0.504  0.004  0.154   7.2  15.7  ...  140   20
# 11  2007   28  60   638  10.4  0.443  0.004  0.132   7.6  13.7  ...  119   16
# 12  2008   29  73  1096   9.8  0.500  0.006  0.076   7.0  13.6  ...  196   44
# 13  2009   30  49   579   7.3  0.435  0.006  0.124   6.8  14.5  ...  103   35
# 14  2010   31  51   456   5.9  0.431  0.052  0.112   9.2  11.5  ...   82   16
#
#     STL  BLK  TOV   PF   PTS  year_start  weight  Status
# 0     6    3    7   26    57        1998     223       6
# 1    87   38  212  240  1608        1997     225       7
# 2    68   37  184  222  1384        1997     225       8
# 3    49   26  117  150   909        1997     225       9
# 4    48   42  108  227   887        1997     225      10
# 5    53   40  116  243   793        1997     225      11
# 6    31    6   68  125   523        2001     205       3
# 7    37   78  128  234   767        2002     255       2
# 8    12   28   27   81   191        2002     255       3
# 9     9   22   18   53   194        2002     255       4
# 10   14   16   34   92   266        2002     255       5
# 11   17   16   21   85   242        2002     255       6
# 12   19   31   45  149   338        2002     255       7
# 13    7   12   20   89   156        2002     255       8
# 14   11    5   22   68   105        2002     255       9
#
# [15 rows x 47 columns]

# %%
# summarize the nba_data
nba_data.describe()
# Out:
#               Year          Age            G           MP          PER  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean   2010.168181    26.614220    58.027579  1368.446517    13.204193
# std       4.311041     4.225402    20.839700   860.169059     4.656013
# min    2003.000000    18.000000    11.000000    31.000000    -9.100000
# 25%    2006.000000    23.000000    43.000000   600.000000    10.300000
# 50%    2010.000000    26.000000    64.000000  1325.000000    13.000000
# 75%    2014.000000    30.000000    76.000000  2066.000000    15.900000
# max    2017.000000    42.000000    85.000000  3401.000000    31.700000
#
#                TS%         3PAr          FTr         ORB%         DRB%  ...  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000  ...
# mean      0.518046     0.224275     0.296625     5.653228    14.582544  ...
# std       0.062482     0.202405     0.161223     4.027958     5.680427  ...
# min       0.125000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.487000     0.013000     0.189000     2.200000    10.000000  ...
# 50%       0.524000     0.209000     0.268000     4.400000    13.600000  ...
# 75%       0.556000     0.382000     0.371000     8.600000    18.400000  ...
# max       0.737000     0.941000     2.400000    27.200000    38.600000  ...
#
#                TRB          AST          STL          BLK          TOV  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean    238.516659   122.077794    42.679420    27.359955    78.094532
# std     194.607052   133.931774    33.637848    34.168039    61.153452
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      90.000000    29.000000    15.000000     6.000000    29.000000
# 50%     191.000000    77.000000    36.000000    16.000000    64.000000
# 75%     332.000000   164.000000    62.000000    34.000000   112.000000
# max    1226.000000   925.000000   217.000000   307.000000   464.000000
#
#                 PF          PTS   year_start       weight       Status
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean    119.010681   559.585525  2005.327754   221.479675     5.840427
# std      68.348529   462.276023     5.772833    27.041645     4.017287
# min       0.000000     2.000000  1985.000000   135.000000     1.000000
# 25%      62.000000   182.000000  2001.000000   200.000000     2.000000
# 50%     119.000000   452.000000  2005.000000   220.000000     5.000000
# 75%     170.000000   828.000000  2010.000000   240.000000     9.000000
# max     344.000000  2832.000000  2017.000000   308.000000    21.000000
#
# [8 rows x 47 columns]

# %%
nba_data.nunique()
# Out:
# Year            15
# Age             25
# G               75
# MP            2675
# PER            306
# TS%            410
# 3PAr           749
# FTr            751
# ORB%           189
# DRB%           304
# TRB%           227
# AST%           451
# STL%            49
# BLK%            97
# TOV%           297
# USG%           296
# OWS            154
# DWS             81
# WS             182
# WS/48          409
# OBPM           204
# DBPM           126
# BPM            240
# VORP           110
# FG             714
# FGA           1345
# FG%            414
# 3P             233
# 3PA            527
# 2P             634
# 2PA           1135
# 2P%            407
# eFG%           406
# FT             502
# FTA            597
# ORB            305
# DRB            629
# TRB            821
# AST            599
# STL            181
# BLK            211
# TOV            302
# PF             304
# PTS           1596
# year_start      32
# weight         117
# Status          21
# dtype: int64

# %%
nba_data.dtypes
# Out:
# Year            int64
# Age             int64
# G               int64
# MP              int64
# PER           float64
# TS%           float64
# 3PAr          float64
# FTr           float64
# ORB%          float64
# DRB%          float64
# TRB%          float64
# AST%          float64
# STL%          float64
# BLK%          float64
# TOV%          float64
# USG%          float64
# OWS           float64
# DWS           float64
# WS            float64
# WS/48         float64
# OBPM          float64
# DBPM          float64
# BPM           float64
# VORP          float64
# FG              int64
# FGA             int64
# FG%           float64
# 3P              int64
# 3PA             int64
# 2P              int64
# 2PA             int64
# 2P%           float64
# eFG%          float64
# FT              int64
# FTA             int64
# ORB             int64
# DRB             int64
# TRB             int64
# AST             int64
# STL             int64
# BLK             int64
# TOV             int64
# PF              int64
# PTS             int64
# year_start      int64
# weight          int64
# Status          int64
# dtype: object

# %%
nba_data.shape
# Out:
# (6273, 47)

# %%
# Print all Columns
print(nba_data.columns.tolist())
# Out:
# ['Year', 'Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year_start', 'weight', 'Status']

# %%
# List NA
nba_data.isna().sum()
# Out:
# Year          0
# Age           0
# G             0
# MP            0
# PER           0
# TS%           0
# 3PAr          0
# FTr           0
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          0
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# year_start    0
# weight        0
# Status        0
# dtype: int64

# %%
nba_data.dropna()
# Out:
#       Year  Age   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  ...  TRB  \
# 0     2003   28  14   204  12.4  0.470  0.017  0.103   7.6  14.0  ...   40
# 1     2003   26  81  3087  19.9  0.566  0.051  0.457   6.7  17.8  ...  677
# 2     2004   27  85  2684  19.9  0.557  0.032  0.407   8.2  19.0  ...  639
# 3     2005   28  54  1867  18.7  0.581  0.058  0.379   7.9  16.0  ...  392
# 4     2006   29  72  1961  17.2  0.588  0.035  0.440   6.4  14.8  ...  357
# ...    ...  ...  ..   ...   ...    ...    ...    ...   ...   ...  ...  ...
# 6268  2017   22  30   557   8.9  0.511  0.371  0.192   3.0  11.2  ...   69
# 6269  2017   24  14    44   6.7  0.437  0.929  0.143   9.9  14.9  ...   10
# 6270  2017   20  19   108   7.3  0.346  0.000  0.161  10.8  24.9  ...   35
# 6271  2017   22  44   843   6.9  0.503  0.448  0.181   1.9  14.2  ...  125
# 6272  2017   19  38   609  17.0  0.547  0.013  0.206   7.1  21.9  ...  159
#
#       AST  STL  BLK  TOV   PF   PTS  year_start  weight  Status
# 0      21    6    3    7   26    57        1998     223       6
# 1     242   87   38  212  240  1608        1997     225       7
# 2     174   68   37  184  222  1384        1997     225       8
# 3     111   49   26  117  150   909        1997     225       9
# 4     149   48   42  108  227   887        1997     225      10
# ...   ...  ...  ...  ...  ...   ...         ...     ...     ...
# 6268   25   27   10   33   60   185        2017     218       1
# 6269    2    3    1    5    4    13        2017     240       1
# 6270    4    2    5    3   17    23        2017     240       1
# 6271   36   15   16   40   78   240        2017     215       1
# 6272   30   14   33   30   66   284        2017     265       1
#
# [6273 rows x 47 columns]

# %%
nba_data.isna().sum()
# Out:
# Year          0
# Age           0
# G             0
# MP            0
# PER           0
# TS%           0
# 3PAr          0
# FTr           0
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          0
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# year_start    0
# weight        0
# Status        0
# dtype: int64

# %% [markdown]
# ## Principal Component Analysis
# ### https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c

# %%
# df.dropna(how="all", inplace=True) # drops the empty line at file-end

# %%
nba_data.describe()
# Out:
#               Year          Age            G           MP          PER  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean   2010.168181    26.614220    58.027579  1368.446517    13.204193
# std       4.311041     4.225402    20.839700   860.169059     4.656013
# min    2003.000000    18.000000    11.000000    31.000000    -9.100000
# 25%    2006.000000    23.000000    43.000000   600.000000    10.300000
# 50%    2010.000000    26.000000    64.000000  1325.000000    13.000000
# 75%    2014.000000    30.000000    76.000000  2066.000000    15.900000
# max    2017.000000    42.000000    85.000000  3401.000000    31.700000
#
#                TS%         3PAr          FTr         ORB%         DRB%  ...  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000  ...
# mean      0.518046     0.224275     0.296625     5.653228    14.582544  ...
# std       0.062482     0.202405     0.161223     4.027958     5.680427  ...
# min       0.125000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.487000     0.013000     0.189000     2.200000    10.000000  ...
# 50%       0.524000     0.209000     0.268000     4.400000    13.600000  ...
# 75%       0.556000     0.382000     0.371000     8.600000    18.400000  ...
# max       0.737000     0.941000     2.400000    27.200000    38.600000  ...
#
#                TRB          AST          STL          BLK          TOV  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean    238.516659   122.077794    42.679420    27.359955    78.094532
# std     194.607052   133.931774    33.637848    34.168039    61.153452
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      90.000000    29.000000    15.000000     6.000000    29.000000
# 50%     191.000000    77.000000    36.000000    16.000000    64.000000
# 75%     332.000000   164.000000    62.000000    34.000000   112.000000
# max    1226.000000   925.000000   217.000000   307.000000   464.000000
#
#                 PF          PTS   year_start       weight       Status
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean    119.010681   559.585525  2005.327754   221.479675     5.840427
# std      68.348529   462.276023     5.772833    27.041645     4.017287
# min       0.000000     2.000000  1985.000000   135.000000     1.000000
# 25%      62.000000   182.000000  2001.000000   200.000000     2.000000
# 50%     119.000000   452.000000  2005.000000   220.000000     5.000000
# 75%     170.000000   828.000000  2010.000000   240.000000     9.000000
# max     344.000000  2832.000000  2017.000000   308.000000    21.000000
#
# [8 rows x 47 columns]

# %%
 iris_scaled = StandardScaler().fit_transform(nba_data)
print(iris_scaled[0:5])
# Out:
# [[-1.66288214  0.3279903  -2.11284658 -1.35384937 -0.17273505 -0.76901737
#   -1.02413819 -1.20107237  0.48335338 -0.10256107  0.15254842  0.27017459
#   -0.12586035 -0.32690739 -0.7897534  -0.74657275 -0.60948998 -0.98839429
#   -0.82697205  0.35109489 -0.01073215  0.51155514  0.26819008 -0.41496879
#   -1.0794891  -1.11616743  0.3444179  -0.78985926 -0.83402936 -0.97326084
#   -1.0033584   0.09478142 -0.23644875 -0.93504946 -0.96730028 -0.79817774
#   -1.06218637 -1.02017107 -0.75475631 -1.09050803 -0.71300249 -1.16265226
#   -1.36093778 -1.08728458 -1.26945272  0.05622611  0.03972469]
#  [-1.66288214 -0.1453752   1.10242724  1.99808452  1.4382135   0.76753748
#   -0.85614517  0.9948155   0.25989729  0.56645605  0.53110094  0.19324788
#   -0.12586035 -0.45240478 -0.19886698  1.12728976  2.74104319  0.75776542
#    2.25093408  1.08637635  1.18306222 -0.10774447  0.93963104  1.48633723
#    2.11770302  1.99496008  0.52199843 -0.35817522 -0.37300865  2.53845392
#    2.59943153  0.25569577  0.09191338  3.28339183  3.00887064  1.82166178
#    2.32054273  2.25335254  0.89546911  1.31768575  0.31142825  2.18983781
#    1.77032287  2.2681212  -1.44269171  0.130192    0.28866875]
#  [-1.43090109  0.09130755  1.29438389  1.52953462  1.4382135   0.62348546
#   -0.95002362  0.68466184  0.63232411  0.77772461  0.77604669 -0.07050082
#   -0.27874997 -0.38965608 -0.22075166  1.1680259   2.13608581  0.50831403
#    1.72140185  0.99251063  0.89365752 -0.44554426  0.51235043  0.64131234
#    1.73214182  1.63821746  0.4776033  -0.60485182 -0.57617032  2.1791472
#    2.25131956  0.21181004 -0.01754066  2.51809938  2.17647598  2.04947391
#    1.9510009   2.0580717   0.38770744  0.75280079  0.2821588   1.73193673
#    1.50694581  1.78352359 -1.44269171  0.130192    0.5376128 ]
#  [-1.19892005  0.3279903  -0.19328012  0.57964562  1.18046174  1.00762418
#   -0.82155837  0.5109758   0.55783875  0.2495532   0.44202976 -0.24633328
#   -0.27874997 -0.38965608 -0.19886698  0.69956027  1.11231179  0.09256172
#    0.82781619  0.89864491  0.92983311 -0.16404444  0.66495064  0.43005611
#    0.75934125  0.57628593  0.89195786 -0.48151352 -0.53710077  1.02665394
#    0.93660541  0.62141019  0.51409326  1.09017567  0.87585932  0.97550243
#    0.66471105  0.78874622 -0.08271881  0.18791583 -0.03980515  0.63624485
#    0.45343755  0.75591705 -1.44269171  0.130192    0.78655686]
#  [-0.966939    0.56467306  0.67052479  0.68893517  0.85827203  1.11966464
#   -0.93520071  0.88936326  0.18541192  0.03828464  0.10801283  0.02840495
#   -0.43163958 -0.01316392 -0.30829039  0.29219886  1.15884697  0.67461496
#    1.09258231  1.10202063  0.56807724  0.34265525  0.69547069  0.50047485
#    0.72968269  0.47119896  1.21752216 -0.68707735 -0.66993724  1.0605508
#    0.86563112  1.00175319  0.74863764  1.07151     1.05422961  0.69887342
#    0.53679272  0.60888228  0.20103036  0.15818504  0.42850605  0.48906236
#    1.5801061   0.70832264 -1.44269171  0.130192    1.03550091]]

# %%
# Using PCA to reduce dimension to three principal components.
# Initialize PCA model
pca = PCA(n_components=3)
# Get tree principal components for the iris data.
nba_data_pca = pca.fit_transform(iris_scaled)

# %%
# Create a DataFrame with the three principal components.
# Transform PCA to DF
pcs_df = pd.DataFrame(data=nba_data_pca, columns=("PC 1", "PC 2","PC 3"), index=nba_label_df.index)
pcs_df.head(15)
# Out:
#         PC 1      PC 2      PC 3
# 0  -4.241400  0.857309 -0.833945
# 1   9.222855  0.514265  2.730621
# 2   7.342653  1.167219  2.527541
# 3   3.528702  1.185185  0.052877
# 4   4.046283  1.482439 -0.137076
# 5   2.097778  1.383158  1.986342
# 6  -2.277484 -1.954021  2.349672
# 7   0.717573  1.938539  4.214201
# 8  -3.838303  1.877234  1.523369
# 9  -3.066278  2.059089 -0.696571
# 10 -2.748540  1.916708 -0.011495
# 11 -3.476761  1.117170  1.439426
# 12 -2.142467  1.661994  0.517372
# 13 -4.349591  1.157390  1.107779
# 14 -5.103483  0.682470  1.431512

# %%
# Initialize the K-Means model.
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# %% [markdown]
# ### Exploratory Visualization

# %%
nba_data.plot(x ='Age', y='year_start', kind = 'scatter')	
plt.show()

# %%
nba_data.plot(x ='weight', y='VORP', kind = 'bar')
plt.show()

# %% [markdown]
# ## Resources

# %%
### PCA
# https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60


# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
# https://www.analyticsvidhya.com/blog/2016/03/pca-practical-guide-principal-component-analysis-python/
# https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c
# https://towardsdatascience.com/redefining-nba-player-classifications-using-clustering-36a348fa54a8
