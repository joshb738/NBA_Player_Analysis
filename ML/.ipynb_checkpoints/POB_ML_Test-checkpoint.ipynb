# %% [markdown]
# ### Import generic

# %%
#So first we need to cluster the players on height, weight and stats (Use PCA), 
#after that we would ML on the dataset where we have player and their cluster. 
#year they are in and VORP and or total win share.

# %%
# Importing required modules
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

## ML && PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
nba_data = pd.read_csv('Resources/dataset_clean.csv', index_col='Player')

# %% [markdown]
# ## Generic Information

# %%
nba_data.head(15)
# Out:
#                      Year  Age   G    MP   PER    TS%   3PAr    FTr  ORB%  \
# Player
# Tariq Abdul-Wahad    2003   28  14   204  12.4  0.470  0.017  0.103   7.6
# Shareef Abdur-Rahim  2003   26  81  3087  19.9  0.566  0.051  0.457   6.7
# Shareef Abdur-Rahim  2004   27  85  2684  19.9  0.557  0.032  0.407   8.2
# Shareef Abdur-Rahim  2005   28  54  1867  18.7  0.581  0.058  0.379   7.9
# Shareef Abdur-Rahim  2006   29  72  1961  17.2  0.588  0.035  0.440   6.4
# Shareef Abdur-Rahim  2007   30  80  2015  13.1  0.524  0.031  0.358   7.0
# Courtney Alexander   2003   25  66  1360   9.3  0.459  0.113  0.289   3.3
# Malik Allen          2003   24  80  2318   9.9  0.455  0.005  0.153   6.5
# Malik Allen          2004   25  45   616  10.5  0.449  0.000  0.167   7.9
# Malik Allen          2005   26  36   519  14.2  0.512  0.000  0.158   9.0
# Malik Allen          2006   27  54   701  11.5  0.504  0.004  0.154   7.2
# Malik Allen          2007   28  60   638  10.4  0.443  0.004  0.132   7.6
# Malik Allen          2008   29  73  1096   9.8  0.500  0.006  0.076   7.0
# Malik Allen          2009   30  49   579   7.3  0.435  0.006  0.124   6.8
# Malik Allen          2010   31  51   456   5.9  0.431  0.052  0.112   9.2
#
#                      DRB%  ...  AST  STL  BLK  TOV   PF   PTS  year_start  \
# Player                     ...
# Tariq Abdul-Wahad    14.0  ...   21    6    3    7   26    57        1998
# Shareef Abdur-Rahim  17.8  ...  242   87   38  212  240  1608        1997
# Shareef Abdur-Rahim  19.0  ...  174   68   37  184  222  1384        1997
# Shareef Abdur-Rahim  16.0  ...  111   49   26  117  150   909        1997
# Shareef Abdur-Rahim  14.8  ...  149   48   42  108  227   887        1997
# Shareef Abdur-Rahim  16.4  ...  109   53   40  116  243   793        1997
# Courtney Alexander    6.8  ...   79   31    6   68  125   523        2001
# Malik Allen          14.9  ...   54   37   78  128  234   767        2002
# Malik Allen          14.7  ...   16   12   28   27   81   191        2002
# Malik Allen          13.3  ...   18    9   22   18   53   194        2002
# Malik Allen          15.7  ...   20   14   16   34   92   266        2002
# Malik Allen          13.7  ...   16   17   16   21   85   242        2002
# Malik Allen          13.6  ...   44   19   31   45  149   338        2002
# Malik Allen          14.5  ...   35    7   12   20   89   156        2002
# Malik Allen          11.5  ...   16   11    5   22   68   105        2002
#
#                      height  weight  Status
# Player
# Tariq Abdul-Wahad       6-6     223       6
# Shareef Abdur-Rahim     6-9     225       7
# Shareef Abdur-Rahim     6-9     225       8
# Shareef Abdur-Rahim     6-9     225       9
# Shareef Abdur-Rahim     6-9     225      10
# Shareef Abdur-Rahim     6-9     225      11
# Courtney Alexander      6-5     205       3
# Malik Allen            6-10     255       2
# Malik Allen            6-10     255       3
# Malik Allen            6-10     255       4
# Malik Allen            6-10     255       5
# Malik Allen            6-10     255       6
# Malik Allen            6-10     255       7
# Malik Allen            6-10     255       8
# Malik Allen            6-10     255       9
#
# [15 rows x 52 columns]

# %%
# summarize the nba_data
nba_data.describe()
# Out:
#               Year          Age            G           MP          PER  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean   2010.168181    26.614220    58.027579  1368.446517    13.204193
# std       4.311041     4.225402    20.839700   860.169059     4.656013
# min    2003.000000    18.000000    11.000000    31.000000    -9.100000
# 25%    2006.000000    23.000000    43.000000   600.000000    10.300000
# 50%    2010.000000    26.000000    64.000000  1325.000000    13.000000
# 75%    2014.000000    30.000000    76.000000  2066.000000    15.900000
# max    2017.000000    42.000000    85.000000  3401.000000    31.700000
#
#                TS%         3PAr          FTr         ORB%         DRB%  ...  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000  ...
# mean      0.518046     0.224275     0.296625     5.653228    14.582544  ...
# std       0.062482     0.202405     0.161223     4.027958     5.680427  ...
# min       0.125000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.487000     0.013000     0.189000     2.200000    10.000000  ...
# 50%       0.524000     0.209000     0.268000     4.400000    13.600000  ...
# 75%       0.556000     0.382000     0.371000     8.600000    18.400000  ...
# max       0.737000     0.941000     2.400000    27.200000    38.600000  ...
#
#                TRB          AST          STL          BLK          TOV  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean    238.516659   122.077794    42.679420    27.359955    78.094532
# std     194.607052   133.931774    33.637848    34.168039    61.153452
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      90.000000    29.000000    15.000000     6.000000    29.000000
# 50%     191.000000    77.000000    36.000000    16.000000    64.000000
# 75%     332.000000   164.000000    62.000000    34.000000   112.000000
# max    1226.000000   925.000000   217.000000   307.000000   464.000000
#
#                 PF          PTS   year_start       weight       Status
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean    119.010681   559.585525  2005.327754   221.479675     5.840427
# std      68.348529   462.276023     5.772833    27.041645     4.017287
# min       0.000000     2.000000  1985.000000   135.000000     1.000000
# 25%      62.000000   182.000000  2001.000000   200.000000     2.000000
# 50%     119.000000   452.000000  2005.000000   220.000000     5.000000
# 75%     170.000000   828.000000  2010.000000   240.000000     9.000000
# max     344.000000  2832.000000  2017.000000   308.000000    21.000000
#
# [8 rows x 51 columns]

# %%
nba_data.nunique()
# Out:
# Year            15
# Age             25
# G               75
# MP            2675
# PER            306
# TS%            410
# 3PAr           749
# FTr            751
# ORB%           189
# DRB%           304
# TRB%           227
# AST%           451
# STL%            49
# BLK%            97
# TOV%           297
# USG%           296
# blanl            0
# OWS            154
# DWS             81
# WS             182
# WS/48          409
# blank2           0
# OBPM           204
# DBPM           126
# BPM            240
# VORP           110
# FG             714
# FGA           1345
# FG%            414
# 3P             233
# 3PA            527
# 3P%            351
# 2P             634
# 2PA           1135
# 2P%            407
# eFG%           406
# FT             502
# FTA            597
# FT%            561
# ORB            305
# DRB            629
# TRB            821
# AST            599
# STL            181
# BLK            211
# TOV            302
# PF             304
# PTS           1596
# year_start      32
# height          21
# weight         117
# Status          21
# dtype: int64

# %%
nba_data.dtypes
# Out:
# Year            int64
# Age             int64
# G               int64
# MP              int64
# PER           float64
# TS%           float64
# 3PAr          float64
# FTr           float64
# ORB%          float64
# DRB%          float64
# TRB%          float64
# AST%          float64
# STL%          float64
# BLK%          float64
# TOV%          float64
# USG%          float64
# blanl         float64
# OWS           float64
# DWS           float64
# WS            float64
# WS/48         float64
# blank2        float64
# OBPM          float64
# DBPM          float64
# BPM           float64
# VORP          float64
# FG              int64
# FGA             int64
# FG%           float64
# 3P              int64
# 3PA             int64
# 3P%           float64
# 2P              int64
# 2PA             int64
# 2P%           float64
# eFG%          float64
# FT              int64
# FTA             int64
# FT%           float64
# ORB             int64
# DRB             int64
# TRB             int64
# AST             int64
# STL             int64
# BLK             int64
# TOV             int64
# PF              int64
# PTS             int64
# year_start      int64
# height         object
# weight          int64
# Status          int64
# dtype: object

# %%
# Print all Columns
print(nba_data.columns.tolist())
# Out:
# ['Year', 'Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year_start', 'height', 'weight', 'Status']

# %% [markdown]
# ## Principal Component Analysis
# ### https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c

# %%
# df.dropna(how="all", inplace=True) # drops the empty line at file-end

# %%
X = nba_data.iloc[:,0:50].values
X
# Out:
# array([[2003, 28, 14, ..., 57, 1998, '6-6'],
#        [2003, 26, 81, ..., 1608, 1997, '6-9'],
#        [2004, 27, 85, ..., 1384, 1997, '6-9'],
#        ...,
#        [2017, 20, 19, ..., 23, 2017, '7-0'],
#        [2017, 22, 44, ..., 240, 2017, '6-8'],
#        [2017, 19, 38, ..., 284, 2017, '7-1']], dtype=object)

# %%
y = nba_data.iloc[:,50].values
y
# Out:
# array([223, 225, 225, ..., 240, 215, 265])

# %% [markdown]
# ### Exploratory Visualization

# %%
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(8, 6))
    for cnt in range(4):
        plt.subplot(2, 2, cnt+1)
        for lab in ('Iris-setosa', 'Iris-versicolor', 'Iris-virginica'):
            plt.hist(X[y==lab, cnt],
                     label=lab,
                     bins=10,
                     alpha=0.3,)
    plt.xlabel(feature_dict[cnt])
    plt.legend(loc='upper right', fancybox=True, fontsize=8)

    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-16-4b462bbaf1e1>:6: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   plt.hist(X[y==lab, cnt],
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4b462bbaf1e1> in <module>
#       8                      bins=10,
#       9                      alpha=0.3,)
# ---> 10     plt.xlabel(feature_dict[cnt])
#      11     plt.legend(loc='upper right', fancybox=True, fontsize=8)
#      12
#
# NameError: name 'feature_dict' is not defined

# %% [markdown]
# ### Standardizing

# %%
X_std = StandardScaler().fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c60a4ee4d2fa> in <module>
# ----> 1 X_std = StandardScaler().fit_transform(X)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '6-6'

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
# https://www.analyticsvidhya.com/blog/2016/03/pca-practical-guide-principal-component-analysis-python/
# https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c
# https://towardsdatascience.com/redefining-nba-player-classifications-using-clustering-36a348fa54a8
