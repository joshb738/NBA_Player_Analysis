# %%
import pandas as pd
import sqlalchemy
import sqlite3

# %%
df = pd.read_csv ('Data/finalized_data.csv', encoding="ISO-8859-1")
c_df = pd.read_csv ('Data/clustered_dataset.csv', encoding="ISO-8859-1")
v_df = pd.read_csv ('Data/for_vis_dataset.csv', encoding="ISO-8859-1")

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///save_pandas.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2021-06-06 13:32:19,692 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-06-06 13:32:19,695 INFO sqlalchemy.engine.base.Engine ()
# 2021-06-06 13:32:19,695 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-06-06 13:32:19,695 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "Player_Dataset"
df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')

sqlite_table2 = "Clustered_Dataset"
c_df.to_sql(sqlite_table2, sqlite_connection, if_exists='fail')

sqlite_table2 = "Visualization_Dataset"
v_df.to_sql(sqlite_table2, sqlite_connection, if_exists='fail')
# Out:
# 2021-06-06 13:32:20,493 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Player_Dataset")
# 2021-06-06 13:32:20,494 INFO sqlalchemy.engine.base.Engine ()
# 2021-06-06 13:32:20,494 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("Player_Dataset")
# 2021-06-06 13:32:20,495 INFO sqlalchemy.engine.base.Engine ()
# 2021-06-06 13:32:20,499 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Player_Dataset" (
# 	"index" BIGINT,
# 	"Year" BIGINT,
# 	"Player" TEXT,
# 	"Age" BIGINT,
# 	"G" BIGINT,
# 	"MP" BIGINT,
# 	"PER" FLOAT,
# 	"TS%" FLOAT,
# 	"3PAr" FLOAT,
# 	"FTr" FLOAT,
# 	"ORB%" FLOAT,
# 	"DRB%" FLOAT,
# 	"TRB%" FLOAT,
# 	"AST%" FLOAT,
# 	"STL%" FLOAT,
# 	"BLK%" FLOAT,
# 	"TOV%" FLOAT,
# 	"USG%" FLOAT,
# 	"OWS" FLOAT,
# 	"DWS" FLOAT,
# 	"WS" FLOAT,
# 	"WS/48" FLOAT,
# 	"OBPM" FLOAT,
# 	"DBPM" FLOAT,
# 	"BPM" FLOAT,
# 	"VORP" FLOAT,
# 	"FG" BIGINT,
# 	"FGA" BIGINT,
# 	"3P" BIGINT,
# 	"3PA" BIGINT,
# 	"2P" BIGINT,
# 	"2PA" BIGINT,
# 	"eFG%" FLOAT,
# 	"FT" BIGINT,
# ...

# %%
sqlite_connection.close()

# %%
import sqlite3

con = sqlite3.connect("save_pandas.db")

cur = con.cursor()

for row in cur.execute('SELECT * FROM "Clustered_Dataset";'):
    print(row)
# Out:
# (0, 'Tariq Abdul-Wahad', 1974, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 4.0, 0.1, 0.4, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# (1, 'Shareef Abdur-Rahim', 1976, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 8.0, 2.8, 9.7, 8.0, 1.6, 8.1, 7.0, 1.3, 5.4, 7.0, 1.4, 6.2, 7.0, -0.1, 2.8, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ...
